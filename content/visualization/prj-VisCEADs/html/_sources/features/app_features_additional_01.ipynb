# %% [raw]
# !pip install ipypublish
# !pip install jupyterlab_myst

# %%
import holoviews as hv
hv.extension('bokeh')
import panel as pn
pn.extension(design='fast')     
pn.extension('tabulator')
pn.extension('echarts')  # ECharts
# ---
## import local modules from sibling folders
import sys
# append the path of the parent directory
sys.path.append("..")
# ---
from pyVisCEADs import pyVisCEADs as VC
locale = VC.locale
UI_label = VC.UI_label

# ---
## 副表及副图：投入产出行业数据及可视化
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6ad066ad-3b1e-4dca-aa81-2a324760412f'>
#   <div id="c04d739a-f52d-4334-8cd1-8cb82ad052ce" data-root-id="6ad066ad-3b1e-4dca-aa81-2a324760412f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# <script type="module" src="https://cdn.holoviz.org/panel/1.4.2/dist/bundled/@microsoft/fast-components@2.30.6/dist/fast-components.js"></script>
# <script type="module" src="https://cdn.holoviz.org/panel/1.4.2/dist/bundled/fast/js/fast_design.js"></script>
#
# ## 分页1行业表
#
# ```分页1行业表```提供表格，供用户比较节点行业部门的``指标信息``。
#
# ### 示意展示图
# 下图仅为展示，完整交互功能见[VisCEADs仪表盘](https://oxon8.netlify.app/visualization/prj-VisCEADs/index.zh)。

# %%
VC.pn_Node
# Out:
# Column(design=<class 'panel.theme.fast.F..., sizing_mode='stretch_height', width=800)
#     [0] Row(design=<class 'panel.theme.fast.F...)
#         [0] Select(design=<class 'panel.theme.fast.F..., name='选择指标（主要）', options=OrderedDict({'CO2排放': 'CO2...]), value='CO2排放', width=200)
#         [1] Select(design=<class 'panel.theme.fast.F..., name='选择指标（次要）', options=OrderedDict({'总投入': '总投入',...]), value='出口', width=200)
#         [2] Select(design=<class 'panel.theme.fast.F..., name='选择指标（任选）', options=OrderedDict({'总投入': '总投入',...]), value='碳排强度', width=200)
#     [1] Tabs(design=<class 'panel.theme.fast.F..., stylesheets=['\n.bk-header {...])
#         [0] ParamFunction(function, _pane=Tabulator, defer_load=False, design=<class 'panel.theme.fast.F..., name='主要')
#         [1] ParamFunction(function, _pane=Tabulator, defer_load=False, design=<class 'panel.theme.fast.F..., name='次要')
# ...

# %% [markdown]
# ### 指标 ``主要``、 ``次要``、``任选`` 共三项选择器及分页，含基本统计
#
# 此处分别有：``主要``、 ``次要``、``任选`` 共三项选择器及分页可供用户对产业的 ``产值`` 及 ``环境影响`` 进行探究比较。
#
# `````{admonition} CEADs 指标信息 （含延伸指标）
# :class: note
# 此处含进口出口等计有 ``16（原数据共 30）指标``，并列出投入 `百分位排名`、`百分比`、`排名`、`值` 等基本统计及信息。。
# `````
#
# -----
#
#
# ### 主要指标如 ``二氧化碳排放`` 及 ``碳排強度`` 要降多少？
#
# 主要指标如 ``二氧化碳排放`` 及 ``碳排強度`` 要降多少？
#
# PwC 及 澳恪森研究均指出，世界碳排强度需``年均减少17-19%``，才能达《巴黎协定》1.5℃目标。
#
# 中国2024年[《2024—2025年节能降碳行动方案》](https://www.gov.cn/zhengce/202405/content_6954583.htm)要求碳排强度（经济） ``年减3.9%``。
#
# 此表交互可以选定指标间的比较。
#
# :::{admonition} ``二氧化碳排放`` 指标要降多少？
# :class: important
#
# * 中国2024年已下指标要``年减3.9%``左右（``单位国内生产总值二氧化碳排放``，见[《2024—2025年节能降碳行动方案》](https://www.gov.cn/zhengce/202405/content_6954583.htm)，可视为``经济年脱碳率``或``经济碳排强度年減率``）
# * PwC指出，世界碳排强度需``年均减少17.2%``，才能达《巴黎协定》1.5℃目标。见[《2023淨零排放經濟指數報告》（Net Zero Economy Index 2023）](https://www.pwc.tw/zh/news/press-release/press-20231011.html)。
# * 澳恪森研究发现，世界碳排强度需``年均减少19%``，才能达1.5℃目标（见[VisNetZero成果](https://oxon8.netlify.app/visualization/prj-visnetzero/index.zh)）。[包括中国的新兴七国，2030年前需加4倍努力，达到年减9.8-10.3% 的脱碳率](https://oxon8.netlify.app/visualization/prj-visnetzero/netzero.co2pg.e7.zh)，才能达1.5℃目标。近年中国脱碳率表现最好的年份及数据分别为 -7.773%（2015年）、 -7.334%（2016年）、 -6.822%（1980年）、 -6.495%（2014年）、等。最近2021年亦达-4.180%。中国2024年方案指标相比之下并不严苛。
#
# :::

# %% [markdown]
# ### 🛈 此表的交互功能
#
# #### 过滤器：节点
#
# 此处选择器（可多选）方便用户过滤相关产业（节点）。
#
# #### 过滤器：最小值
#
# 此处可设置小值进行过滤。

# %% [markdown]
# ### 🎯CEADs 指标信息 （含延伸指标）
#
# `````{admonition} CEADs 指标信息 （含延伸指标）
# :class: tip
# 此处含进口出口等计有 ``16（原数据共 30）指标``，并列出投入 `百分位排名`、`百分比`、`排名`、`值` 等基本统计及信息。。
# `````
